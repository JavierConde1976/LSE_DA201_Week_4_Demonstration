# %% [markdown]
# ### LSE Data Analytics Online Career Accelerator
#
# # DA201: Data Analytics Using Python

# %% [markdown]
# ## Week 4: Data visualisation with Python

# %% [markdown]
# The focus this week is on data visualisation with Python.
#
# This is your notebook. You will use this notebook to follow along with the demonstrations throughout the week. Use it to test ideas, and explore what is possible. The hands-on experience of writing your own code will accelarate your learning!
#
# Learn about using your Jupyter Notebook here: https://jupyter-notebook.readthedocs.io/en/latest/ui_components.html.

# %% [markdown]
# ### 4.1 Data visualisation with Seaborn

# %%
import matplotlib.pyplot as plt

# %%
fig,ax = plt.subplots()

# %%
ax.plot([1, 2, 3, 4], [8, 6, 4, 2])

# %%
fig

# %% [markdown]
# #

# %%
# Create a 2 x 2 figure by specifying the nrows and ncols parameters.
fig2, ((top_left, top_right), (bottom_left, bottom_right)) = plt.subplots(2, 2)

# %%
# Specify each variable.
top_left.plot([1, 2, 3, 4], [1, 1, 1, 1], color='blue')
top_right.plot([1, 2, 3, 4], [1,1,1,1], color='red')
bottom_left.plot([1, 2, 3, 4], [1,1,1,1], color='black')
bottom_right.plot([1, 2, 3, 4], [1,1,1,1], color='orange')

# %%
fig2

# %%
# Set the background colour of the figure.
fig2.set_facecolor('yellow')

# %%
fig2

# %%
# Specify three arguments (y-values, x-values, and marker) without a line.
ax.clear()
ax.plot([0, 1, 2, 3, 4], [4, 3, 2, 1, 0], 'xb')

# View figure.
fig

# %%
# Specify three arguments (y-values, x-values, and marker) without a line.
ax.clear()
ax.plot([0, 1, 2, 3, 4], [4, 3, 2, 1, 0], 'xb')

# View figure.
fig

# %%
# Specify various named arguments.
ax.clear()
ax.plot([0, 1, 2, 3, 4],
        [4, 3, 2, 1, 0],
      color='#94CEE4',
      marker='x',
      markeredgecolor='red',
        drawstyle='steps',
        linestyle=':')

# View figure.
fig

# %%
# Import Matplotlib, Seaborn and Pandas.
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# Syntax for stripplot function in Seaborn.
sns.stripplot()
# Out:
# <AxesSubplot:>

# %%
# Syntax for boxplot function in Seaborn.
sns.boxplot()
# Out:
# <AxesSubplot:>

# %%
sns.barplot()
# Out:
# <AxesSubplot:>

# %%
# Import Matplotlib.
import matplotlib.pyplot as plt

# Clear the axes.
ax.clear()

# Draw a line by specifying the axes.
ax.plot([1, 2, 3, 4], [4, 3, 2, 1])

# View the Figure.
fig

# %%
# Import Seaborn.
import seaborn as sns

# Create a plot.
sns.relplot(x=[1, 2, 3, 4], y=[4, 3, 2, 1], kind='line')

# %% [markdown]
# ### 4.1.4 Countplots with Seaborn

# %%
# Import Matplotlib, Seaborn and Pandas.
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# Import CSV with Pandas "read_csv".
penguins = pd.read_csv('penguins.csv')

# %%
# Create a VERTICAL countplot with Seaborn.
sns.countplot(x='island', data=penguins)
# Out:
# <AxesSubplot:xlabel='island', ylabel='count'>

# %%
# Create a HORIZONTAL countplot with Seaborn.
sns.countplot(y='island', data=penguins)
# Out:
# <AxesSubplot:xlabel='count', ylabel='island'>

# %%
# Create a countplot with Seaborn.
sns.countplot(x='island', hue='species', data=penguins)
# Out:
# <AxesSubplot:xlabel='island', ylabel='count'>

# %% [markdown]
# ### 4.1.5 Pointplots with Seaborn.

# %%
# Import CSV for MPG cars
mpg = pd.read_csv('mpg.csv')

# %%
# Create a pointplot with Seaborn.
sns.pointplot(x='model_year', y= 'mpg', hue = 'origin', data=mpg)
# Out:
# <AxesSubplot:xlabel='model_year', ylabel='mpg'>

# %% [markdown]
# ### 4.1.6 Barplots with Seaborn

# %%
# Import Matplotlib, Seaborn and Pandas.
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# Import "daily activity' CSV.

daily_activity = pd.read_csv('daily_activity.csv')

# %%
daily_activity
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    4/12/2016       13162       8.500000         8.500000
# 1    1503960366    4/13/2016       10735       6.970000         6.970000
# 2    1503960366    4/14/2016       10460       6.740000         6.740000
# 3    1503960366    4/15/2016        9762       6.280000         6.280000
# 4    1503960366    4/16/2016       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# 935  8877689391     5/8/2016       10686       8.110000         8.110000
# 936  8877689391     5/9/2016       20226      18.250000        18.250000
# 937  8877689391    5/10/2016       10733       8.150000         8.150000
# 938  8877689391    5/11/2016       21420      19.559999        19.559999
# 939  8877689391    5/12/2016        8064       6.120000         6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
# Create 'distance' dataframe

# Create group 4.
distance = daily_activity[['Id', 'ActivityDate', 'VeryActiveDistance', 
                                   'ModeratelyActiveDistance', 'LightActiveDistance',
                                   'SedentaryActiveDistance']]

# %%
distance
# Out:
#              Id ActivityDate  VeryActiveDistance  ModeratelyActiveDistance  \
# 0    1503960366    4/12/2016                1.88                      0.55
# 1    1503960366    4/13/2016                1.57                      0.69
# 2    1503960366    4/14/2016                2.44                      0.40
# 3    1503960366    4/15/2016                2.14                      1.26
# 4    1503960366    4/16/2016                2.71                      0.41
# ..          ...          ...                 ...                       ...
# 935  8877689391     5/8/2016                1.08                      0.20
# 936  8877689391     5/9/2016               11.10                      0.80
# 937  8877689391    5/10/2016                1.35                      0.46
# 938  8877689391    5/11/2016               13.22                      0.41
# 939  8877689391    5/12/2016                1.82                      0.04
#
#      LightActiveDistance  SedentaryActiveDistance
# ...

# %%
distance_long = pd.melt(distance, id_vars=('Id', 'ActivityDate'), 
                        var_name=('DistanceType'),
                        value_name=('Distance'))

# %%
distance_long
# Out:
#               Id ActivityDate             DistanceType  Distance
# 0     1503960366    4/12/2016       VeryActiveDistance      1.88
# 1     1503960366    4/13/2016       VeryActiveDistance      1.57
# 2     1503960366    4/14/2016       VeryActiveDistance      2.44
# 3     1503960366    4/15/2016       VeryActiveDistance      2.14
# 4     1503960366    4/16/2016       VeryActiveDistance      2.71
# ...          ...          ...                      ...       ...
# 3755  8877689391     5/8/2016  SedentaryActiveDistance      0.00
# 3756  8877689391     5/9/2016  SedentaryActiveDistance      0.05
# 3757  8877689391    5/10/2016  SedentaryActiveDistance      0.00
# 3758  8877689391    5/11/2016  SedentaryActiveDistance      0.00
# 3759  8877689391    5/12/2016  SedentaryActiveDistance      0.00
#
# [3760 rows x 4 columns]

# %%
# Format values in the columns.
distance_long['DistanceType'] = distance_long['DistanceType'].str.replace \
('ActiveDistance', "")

# %%
distance_long
# Out:
#               Id ActivityDate DistanceType  Distance
# 0     1503960366    4/12/2016         Very      1.88
# 1     1503960366    4/13/2016         Very      1.57
# 2     1503960366    4/14/2016         Very      2.44
# 3     1503960366    4/15/2016         Very      2.14
# 4     1503960366    4/16/2016         Very      2.71
# ...          ...          ...          ...       ...
# 3755  8877689391     5/8/2016    Sedentary      0.00
# 3756  8877689391     5/9/2016    Sedentary      0.05
# 3757  8877689391    5/10/2016    Sedentary      0.00
# 3758  8877689391    5/11/2016    Sedentary      0.00
# 3759  8877689391    5/12/2016    Sedentary      0.00
#
# [3760 rows x 4 columns]

# %%
# Add a filter to identify logged-in user.
individual = distance_long[distance_long['Id'] == 1503960366]

# %%
individual
# Out:
#               Id ActivityDate DistanceType  Distance
# 0     1503960366    4/12/2016         Very      1.88
# 1     1503960366    4/13/2016         Very      1.57
# 2     1503960366    4/14/2016         Very      2.44
# 3     1503960366    4/15/2016         Very      2.14
# 4     1503960366    4/16/2016         Very      2.71
# ...          ...          ...          ...       ...
# 2846  1503960366     5/8/2016    Sedentary      0.00
# 2847  1503960366     5/9/2016    Sedentary      0.00
# 2848  1503960366    5/10/2016    Sedentary      0.00
# 2849  1503960366    5/11/2016    Sedentary      0.00
# 2850  1503960366    5/12/2016    Sedentary      0.00
#
# [124 rows x 4 columns]

# %%
#create Simple Barplot.

sns.barplot(x="DistanceType", y="Distance", estimator=sum, data=individual)
# Out:
# <AxesSubplot:xlabel='DistanceType', ylabel='Distance'>

# %%
# create Stacked Barplot (Seaborn not good, we use pandas library)

# Stacked barplots with Pandas.
individual.groupby('DistanceType')[['Distance']].sum().T.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
# Add a filter to identify logged-in user.
pair = distance_long[distance_long['Id'].isin([1503960366, 8877689391])]

# %%
pair
# Out:
#               Id ActivityDate DistanceType  Distance
# 0     1503960366    4/12/2016         Very      1.88
# 1     1503960366    4/13/2016         Very      1.57
# 2     1503960366    4/14/2016         Very      2.44
# 3     1503960366    4/15/2016         Very      2.14
# 4     1503960366    4/16/2016         Very      2.71
# ...          ...          ...          ...       ...
# 3755  8877689391     5/8/2016    Sedentary      0.00
# 3756  8877689391     5/9/2016    Sedentary      0.05
# 3757  8877689391    5/10/2016    Sedentary      0.00
# 3758  8877689391    5/11/2016    Sedentary      0.00
# 3759  8877689391    5/12/2016    Sedentary      0.00
#
# [248 rows x 4 columns]

# %%
# Create a grouped barplot.
sns.barplot(x='DistanceType', y='Distance', hue='Id', estimator=sum, data=pair)
# Out:
# <AxesSubplot:xlabel='DistanceType', ylabel='Distance'>

# %%
# Import Matplotlib, Seaborn, and Pandas.
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Read the CSV file.
fitness = pd.read_csv('daily_activity.csv')

# View the DataFrame.
print(fitness.shape)
print(fitness.dtypes)
print(fitness.columns)
fitness.head()
# Out:
# (940, 15)
# Id                            int64
# ActivityDate                 object
# TotalSteps                    int64
# TotalDistance               float64
# TrackerDistance             float64
# LoggedActivitiesDistance    float64
# VeryActiveDistance          float64
# ModeratelyActiveDistance    float64
# LightActiveDistance         float64
# SedentaryActiveDistance     float64
# VeryActiveMinutes             int64
# FairlyActiveMinutes           int64
# LightlyActiveMinutes          int64
# SedentaryMinutes              int64
# Calories                      int64
# dtype: object
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories'],
#       dtype='object')
# ...

# %%
# Add a filter for the date 4/12/2016 .
single_day = fitness[fitness['ActivityDate'] == '4/12/2016']

# %%
single_day
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    4/12/2016       13162           8.50             8.50
# 31   1624580081    4/12/2016        8163           5.31             5.31
# 62   1644430081    4/12/2016       10694           7.77             7.77
# 92   1844505072    4/12/2016        6697           4.43             4.43
# 123  1927972279    4/12/2016         678           0.47             0.47
# 154  2022484408    4/12/2016       11875           8.34             8.34
# 185  2026352035    4/12/2016        4414           2.74             2.74
# 216  2320127002    4/12/2016       10725           7.49             7.49
# 247  2347167796    4/12/2016       10113           6.83             6.83
# 265  2873212765    4/12/2016        8796           5.91             5.91
# 296  3372868164    4/12/2016        4747           3.24             3.24
# 316  3977333714    4/12/2016        8856           5.98             5.98
# ...

# %%
print(single_day.shape)
# Out:
# (33, 15)

# %%
sns.histplot(x='TotalDistance', data=single_day)
# Out:
# <AxesSubplot:xlabel='TotalDistance', ylabel='Count'>

# %%
# Changing the binsize

sns.histplot(data=single_day, x='TotalDistance', binwidth=1)
# Out:
# <AxesSubplot:xlabel='TotalDistance', ylabel='Count'>

# %%
# Changing the binsize to 2

sns.histplot(data=single_day, x='TotalDistance', binwidth=2)
# Out:
# <AxesSubplot:xlabel='TotalDistance', ylabel='Count'>

# %%
# Changing the binsize to 5

sns.histplot(data=single_day, x='TotalDistance', binwidth=5)
# Out:
# <AxesSubplot:xlabel='TotalDistance', ylabel='Count'>

# %%
# Changing the binsize to 10

sns.histplot(data=single_day, x='TotalDistance', binwidth=10)
# Out:
# <AxesSubplot:xlabel='TotalDistance', ylabel='Count'>

# %%
# Create scatterplot
# Add a filter for the date 4/12/2016 .
single_day = fitness[fitness['ActivityDate'] == '4/12/2016']

# %%
single_day.shape
# Out:
# (33, 15)

# %%
single_day
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    4/12/2016       13162           8.50             8.50
# 31   1624580081    4/12/2016        8163           5.31             5.31
# 62   1644430081    4/12/2016       10694           7.77             7.77
# 92   1844505072    4/12/2016        6697           4.43             4.43
# 123  1927972279    4/12/2016         678           0.47             0.47
# 154  2022484408    4/12/2016       11875           8.34             8.34
# 185  2026352035    4/12/2016        4414           2.74             2.74
# 216  2320127002    4/12/2016       10725           7.49             7.49
# 247  2347167796    4/12/2016       10113           6.83             6.83
# 265  2873212765    4/12/2016        8796           5.91             5.91
# 296  3372868164    4/12/2016        4747           3.24             3.24
# 316  3977333714    4/12/2016        8856           5.98             5.98
# ...

# %%
sns.scatterplot(x = 'TotalDistance', y = 'Calories', data = single_day)
# Out:
# <AxesSubplot:xlabel='TotalDistance', ylabel='Calories'>

# %%
# Scatterplot with 3 variables

# Create a scatterplot with three variables.
sns.scatterplot(x='TotalSteps', y='Calories', marker='o',
                hue='VeryActiveMinutes', size='VeryActiveMinutes',
                legend='full', data=single_day)

# Adjust the legend position.
plt.legend(bbox_to_anchor=(1.05, 1))

# %%
# Create the scatterplot with regression line.
sns.regplot(x='TotalSteps', y='Calories', data=single_day)
# Out:
# <AxesSubplot:xlabel='TotalSteps', ylabel='Calories'>

# %%
# Create the scatterplot with regression line with no confidence interval.
sns.regplot(x='TotalSteps', y='Calories', data=single_day, ci=None)
# Out:
# <AxesSubplot:xlabel='TotalSteps', ylabel='Calories'>

# %% [markdown]
# ### 4.1.10 Outlier analysis: Pairplots

# %%
# Create a simple pairplot.
sns.pairplot(penguins)

# %%
# Create a simple pairplot.
sns.pairplot(data = penguins, hue = 'species')

# %%
# Create a pairplot with the facetgrid method.
sns.pairplot(penguins, hue='species', diag_kind='hist')

# %%
# Remove any redundant plots.
sns.pairplot(penguins,
             x_vars=['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm'],
             y_vars=['bill_length_mm', 'bill_depth_mm'])

# %% [markdown]
# ### 4.1.11 Outlier analysis: Boxplots

# %%
# Create a boxplot based on species and body_mass_g.
sns.boxplot(data=penguins, x='species', y='body_mass_g')
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
# Create a boxplot based on species and body_mass_g with NO OUTLIERS.
sns.boxplot(data=penguins, x='species', y='body_mass_g', showfliers=False)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
# Create a boxplot with a third variable.
sns.boxplot(data=penguins, x='species', y='body_mass_g', hue='sex')
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
# Specify the order of variables. 
my_order = penguins.groupby(by=['species'])['body_mass_g'].median().iloc[::-1].index

# Create a boxplot based on the order of variables.
sns.boxplot(x='species', y='body_mass_g', data=penguins, order=my_order)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %% [markdown]
# ### 4.1.13 Lineplots with Seaborn

# %%
# Create a simple lineplot.
sns.lineplot(x='ActivityDate', y='TotalSteps', data=fitness)
# Out:
# <AxesSubplot:xlabel='ActivityDate', ylabel='TotalSteps'>

# %%
# Create a simple lineplot without the confidence interval.
sns.lineplot(x='ActivityDate', y='TotalSteps', data=fitness, ci=None)
# Out:
# <AxesSubplot:xlabel='ActivityDate', ylabel='TotalSteps'>

# %%
# Create a time-series.
steps_time_series = fitness\
 .groupby('ActivityDate')[['TotalSteps']]\
 .sum()\
 .reset_index()\
 .copy()


# Format data with datetime() function.
steps_time_series['ActivityDate'] = pd.to_datetime(steps_time_series['ActivityDate'])

# View the output.
print(steps_time_series.head())


# Create a lineplot without confidence level shade.
sns.lineplot(x='ActivityDate', y='TotalSteps', data=steps_time_series)
# Out:
#   ActivityDate  TotalSteps
# 0   2016-04-12      271816
# 1   2016-04-13      237558
# 2   2016-04-14      255538
# 3   2016-04-15      248617
# 4   2016-04-16      277733
# <AxesSubplot:xlabel='ActivityDate', ylabel='TotalSteps'>

# %%
# Create plot size.
plt.figure(figsize=(18, 6))

# Create a lineplote with specific date.
sns.lineplot(x='ActivityDate', y='TotalSteps',
             data=steps_time_series[steps_time_series['ActivityDate'] < '2016-05-01'])
# Out:
# <AxesSubplot:xlabel='ActivityDate', ylabel='TotalSteps'>

# %% [markdown]
# ### 4.1.14 Relational plots with Seaborn

# %%
# Create a scatterplot.
sns.scatterplot(x='bill_length_mm', y='flipper_length_mm', hue='sex', data=penguins)
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='flipper_length_mm'>

# %%
# Set the size of the plot.
sns.set(font_scale = 2)

# Create a relational plot.
sns.relplot(x='bill_length_mm', y='flipper_length_mm', hue='sex',
            data=penguins, col='species')

# %%
# Refining/Set the size of the plot.
sns.set(font_scale = 1.5)

# Create a relational plot.
sns.relplot(x='bill_length_mm', y='flipper_length_mm',
            hue='sex', data=penguins, col='species', row='island')

# %% [markdown]
# ### 4.2 Customising plots with Seaborn and Matplotlib

# %% [markdown]
# ### 4.2.4 Customising styles, colours, titles, and labels

# %%
# Import libraries.
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Create an empty plot.
fig, ax = plt.subplots()

# %%
# Create variables.
x = np.linspace(0, 10, 101)
y = np.exp(x)

# %%
# Create plot.
ax.plot(x, y)

# %%
# Visualise plot.
fig

# %%
# Set labels and title.
ax.set_xlabel("Time Elapsed (minutes)")
ax.set_ylabel("Count")
ax.set_title("Bacteria Growth")

# View plot.
fig

# %%
# Add ticks to x-axis.
ax.set_xticks([0, 5, 10])
ax.set_xticks([1, 2, 3, 4, 6, 7, 8, 9], minor=True)

# View figure.
fig

# %%
# Add ticks labels to x-axis.
ax.set_xticklabels(['0.0', '5.0', '10.0'])

# View figure.
fig

# %%
# Add ticks labels to x-axis.
ax.set_xticklabels(['1', '2', '3', '4', '6',
                    '7', '8', '9'], minor=True)

# View figure.
fig

# %%
# Create new variables.
y_no_food = np.exp(x)
y_food = np.exp(x + 1.01)

# Create an empty plot.
fig, ax = plt.subplots()

# Plot the new variables and add the label to the legend.
lines = ax.plot(x, y_no_food)
line = lines[0]

# Set the line variable.
line.set_label("No Food")

# Add legend.
ax.legend()

# %%
# Plot second line.
ax.plot(x, y_food, label="With Food")

# Create legend.
ax.legend()

# Specify legend position.
ax.legend(loc='center left')

# View figure.
fig

# %%
ax.plot([0,12,14,16,18])

# %%
# Import CSV with Pandas "read_csv".
penguins = pd.read_csv('penguins.csv')

# Set figure size.
sns.set(rc={'figure.figsize':(5, 5)})

# Set the tick style.
sns.set_style('ticks')

# Set colour style.
sns.set_style('darkgrid')

# Plot scatterplot.
sns.scatterplot(data=penguins, x='bill_length_mm', 
                y='flipper_length_mm', hue='species')
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='flipper_length_mm'>

# %%
# Set style of ticks.
sns.set_style('ticks', {'axes.facecolor': '#dddddd',
                       'axes.spines.top': False,
                       'axes.spines.right': False})

# Create scatterplot.
sns.scatterplot(data=penguins, x='bill_length_mm',
              y='flipper_length_mm', hue='species')
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='flipper_length_mm'>

# %%
# Set the style first.
sns.set_style('ticks')

# Specify Pastel palette.
sns.scatterplot(data=penguins, x='bill_length_mm',
                y='flipper_length_mm', hue='species',
                palette='pastel')
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='flipper_length_mm'>

# %%
# Set colour as colorblind.
sns.scatterplot(data=penguins, x='bill_length_mm',
                y='flipper_length_mm', hue='species',
                palette='colorblind')
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='flipper_length_mm'>

# %% [markdown]
# #

# %%
# Plot the scatterplot.
ax = sns.scatterplot(data=penguins, x='bill_length_mm',
                     y='flipper_length_mm', hue='species',
                     palette='colorblind')

# Specify the labels.
ax.set_xlabel("Bill length (mm)")
ax.set_ylabel("Flipper length (mm)")
ax.set_title("Penguins Bill vs. Flipper Length")
# Out:
# Text(0.5, 1.0, 'Penguins Bill vs. Flipper Length')

# %%
# Import Matplotlib, Seaborn, and Pandas.
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Read the CSV file.
fitness = pd.read_csv('daily_activity.csv')

# View the DataFrame.
print(fitness.shape)
print(fitness.dtypes)
print(fitness.columns)
fitness.head()

# Define single_day as variable.
single_day = fitness[fitness['ActivityDate'] == '4/12/2016']

# Create a scatterplot.
sns.scatterplot(x='TotalSteps', y='Calories', data=single_day)

# Make a copy of original data.
single_day_highlights = single_day.copy()

# Set a criteria as true or false.
single_day_highlights['High Activity'] = single_day_highlights['TotalSteps'] > 15000

# Create new scatterplot.
sns.scatterplot(x='TotalSteps', y='Calories', 
                hue='High Activity', data=single_day_highlights)
# Out:
# (940, 15)
# Id                            int64
# ActivityDate                 object
# TotalSteps                    int64
# TotalDistance               float64
# TrackerDistance             float64
# LoggedActivitiesDistance    float64
# VeryActiveDistance          float64
# ModeratelyActiveDistance    float64
# LightActiveDistance         float64
# SedentaryActiveDistance     float64
# VeryActiveMinutes             int64
# FairlyActiveMinutes           int64
# LightlyActiveMinutes          int64
# SedentaryMinutes              int64
# Calories                      int64
# dtype: object
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories'],
#       dtype='object')
# ...

# %%
# Define data = steps_time_series.
steps_time_series = fitness\
 .groupby('ActivityDate')[['TotalSteps']]\
 .sum()\
 .reset_index()\
 .copy()

# Create a variable.
steps_time_series['ActivityDate'] = pd.to_datetime(steps_time_series['ActivityDate'])

# Create a lineplot.
sns.lineplot(x='ActivityDate', y='TotalSteps', data=steps_time_series)

# Add annotation lines.
plt.axhline(y=250000, color='r', linestyle='--')
plt.axhline(y=260000, color='r', linestyle='--')

# %%
# Import flight CSV with Pandas
flights = pd.read_csv('flights.csv')

# %%
# Create empty plot and set plot size.
fig, ax = plt.subplots()
fig.set_size_inches(12, 8)

# Create variable.
august_flights = flights[flights['month'] == 'August']

# Create barplot.
bars = ax.bar(august_flights['year'], august_flights['passengers'], color='lightgrey')

# Annotate a bar.
ax.set_xticks(list(range(1949, 1961, 1)))
bars[4].set_color('blue')

# %%
fig, ax = plt.subplots()
ax.plot([4, 3, 2, 1, 0])

# %%
data_ann = ax.annotate('Data 2, 2', xy=(2,2))

fig

# %%
pixel_ann = ax.annotate('Pixels 2, 2', xy=(2,2), xycoords='axes pixels')

fig

# %%
data_ann.remove()
pixel_ann.remove()
centered_ann = ax.annotate("Centered Data 2, 2",
                           xy=(2,2), horizontalalignment='center',
                           verticalalignment='center')
fig

# %%
centered_ann.remove()
arrow_ann = ax.annotate("Look at point 1, 3", xy=(1, 3),
            xytext=(1, 1.5),
            arrowprops={'facecolor': 'black', 'shrink': 0.05},
            horizontalalignment='center', verticalalignment='top')

fig

# %%
arrow_ann.remove()

# %%
# Import libraries.
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Import flight CSV with Pandas
flights = pd.read_csv('flights.csv')

# Set ticks.
ax.set_xticks(list(range(1949, 1961, 1)))

# Insert labels.
ax.set_title("Air Travel for August")
ax.set_xlabel("Year")
ax.set_ylabel("Passengers")

# Select bars to highlight.
for bar_index in [4, 7]:
    bars[bar_index].set_color('#4472C4')
    row = august_flights.iloc[bar_index]
    passenger_count = row['passengers']
    year = row['year']
    xy = (year, passenger_count)
    
    # Draw a circle on top of bar.
    if bar_index == 7:
        bbox = {'boxstyle': 'circle, pad=0.5', 'fill': True}
    else:
        bbox = None

# Create plot.
ax.annotate("{}".format(passenger_count),
            xy=xy,
            verticalalignment='bottom',
            horizontalalignment='center',
            bbox=bbox)

fig

# %%
xy = (year, passenger_count - 10)
circle_ann = ax.annotate(" ",
            xy=xy,
            verticalalignment='bottom',
            horizontalalignment='center',
            bbox={'boxstyle': 'circle, pad=3', 'fill': False})

circle_ann. remove()
fig

# %%
# Import Seaborn and Matplotlib.
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(dpi=350)

fig.set_size_inches(6, 4)

# %%
fig, ax = plt.subplots(dpi=100)

fig.set_size_inches(8, 6)

# %%
fig, ax = plt.subplots(dpi=100)

fig.set_size_inches(8, 6)

# %% [markdown]
# ### 4.3 Visualisation workflow

# %% [markdown]
# ### 4.3.2 Exploring the data set

# %%
# Import libraries.
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Import marathon_results CSV file with Pandas
marathon = pd.read_csv('marathon_results.csv')

# %% [markdown]
# ### Question 1: What is the spread of the data?

# %%
# Ensure the variables of interest are numeric.
marathon['official_time']=pd.to_timedelta(marathon['Official Time'])

# How many seconds.
marathon['official_time_seconds']=marathon['official_time'].dt.seconds

# How many minutes.
marathon['official_time_minutes']=marathon['official_time_seconds']/60

# View the DataFrame.
marathon.head()
# Out:
#    Unnamed: 0 Bib              Name  Age M/F           City State Country  \
# 0           0  11   Kirui, Geoffrey   24   M       Keringet   NaN     KEN
# 1           1  17       Rupp, Galen   30   M       Portland    OR     USA
# 2           2  23     Osako, Suguru   25   M   Machida-City   NaN     JPN
# 3           3  21  Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA
# 4           4   9    Chebet, Wilson   31   M       Marakwet   NaN     KEN
#
#   Citizen Unnamed: 9  ...      40K     Pace Proj Time Official Time Overall  \
# 0     NaN        NaN  ...  2:02:53  0:04:57         -       2:09:37       1
# 1     NaN        NaN  ...  2:03:14  0:04:58         -       2:09:58       2
# 2     NaN        NaN  ...  2:03:38  0:04:59         -       2:10:28       3
# 3     NaN        NaN  ...  2:04:35  0:05:03         -       2:12:08       4
# 4     NaN        NaN  ...  2:05:00  0:05:04         -       2:12:35       5
#
# ...

# %%
# Create an empty plot and set plot size.
fig, ax = plt.subplots()
fig.set_size_inches(16, 8)

# Create a histogram.
ax.hist(marathon['Official Time'], bins=20)

fig

# %% [markdown]
# ### Question 2: What is the spread of male marathon runners?

# %%
# Create an empty plot and set plot size.
fig, ax = plt.subplots()
fig.set_size_inches(16, 8)

# Create variable for x values.
male = marathon[marathon['M/F'] == 'M']

# Create a histogram.
ax.hist(male['Official Time'], bins=20)

fig

# %% [markdown]
# ### Question 3: What is the spread of female marathon runners?

# %%
# Create an empty plot and set plot size.
fig, ax = plt.subplots()
fig.set_size_inches(16, 8)

# Create variable for x values.
female = marathon[marathon['M/F'] == 'F']

# Create a histogram.
ax.hist(female['Official Time'], bins=20)

fig

# %% [markdown]
# ### Question 4: What is the relationship between gender and race times?

# %%
# Create a data set for males and females to use in the matplotlib boxplot.
males = marathon[marathon['M/F']=='M']

females = marathon[marathon['M/F']=='F']

males = males['official_time_minutes']

females = females['official_time_minutes']

plt.boxplot([males,females], labels=['M','F'], patch_artist=True)

plt.show()

# %%
# Seaborn boxplot.
sns.boxplot(x='M/F', y='official_time_minutes', data=marathon)
# Out:
# <AxesSubplot:xlabel='M/F', ylabel='official_time_minutes'>

# %% [markdown]
# ### PRACTICAL ACTIVITIES

# %% [markdown]
# ### 4.1.9 Practical activity: Create plots with Seaborn

# %%
# Import libraries.
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
movies = pd.read_excel('movies_merge.xlsx')

# %%
ott = pd.read_csv('ott_merge.csv')

# %%
print(movies.head())

print(ott.head())

print(movies.shape)
print(ott.shape)
print(movies.dtypes)
print(ott.dtypes)
# Out:
#    ID                           Title  Year  Age  IMDb  Rotten Tomatoes  \
# 0   1                       Inception  2010  13+   8.8             0.87
# 1   2                      The Matrix  1999  18+   8.7             0.87
# 2   3          Avengers: Infinity War  2018  13+   8.5             0.84
# 3   4              Back to the Future  1985   7+   8.5             0.96
# 4   5  The Good, the Bad and the Ugly  1966  18+   8.8             0.97
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# 1  Lana Wachowski,Lilly Wachowski                     Action,Sci-Fi
# 2         Anthony Russo,Joe Russo           Action,Adventure,Sci-Fi
# 3                 Robert Zemeckis           Adventure,Comedy,Sci-Fi
# 4                    Sergio Leone                           Western
#
#                         Country                 Language  Runtime
# ...

# %%
# Merge both tables

mov_ott = pd.merge(movies, ott)

# %%
print(mov_ott.head())
print(mov_ott.shape)
print(mov_ott.columns)
# Out:
#    ID                           Title  Year  Age  IMDb  Rotten Tomatoes  \
# 0   1                       Inception  2010  13+   8.8             0.87
# 1   2                      The Matrix  1999  18+   8.7             0.87
# 2   3          Avengers: Infinity War  2018  13+   8.5             0.84
# 3   4              Back to the Future  1985   7+   8.5             0.96
# 4   5  The Good, the Bad and the Ugly  1966  18+   8.8             0.97
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# 1  Lana Wachowski,Lilly Wachowski                     Action,Sci-Fi
# 2         Anthony Russo,Joe Russo           Action,Adventure,Sci-Fi
# 3                 Robert Zemeckis           Adventure,Comedy,Sci-Fi
# 4                    Sergio Leone                           Western
#
#                         Country                 Language  Runtime  Netflix  \
# ...

# %%
# countplot with 'Age' - 'Total Streaming'
# df['C'] = df['A'] + df['B']

mov_ott['Streaming'] = mov_ott['Netflix'] + mov_ott['Hulu'] + mov_ott['Prime Video'] + mov_ott['Disney+']

# %%
mov_ott.head()
# Out:
#    ID                           Title  Year  Age  IMDb  Rotten Tomatoes  \
# 0   1                       Inception  2010  13+   8.8             0.87
# 1   2                      The Matrix  1999  18+   8.7             0.87
# 2   3          Avengers: Infinity War  2018  13+   8.5             0.84
# 3   4              Back to the Future  1985   7+   8.5             0.96
# 4   5  The Good, the Bad and the Ugly  1966  18+   8.8             0.97
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# 1  Lana Wachowski,Lilly Wachowski                     Action,Sci-Fi
# 2         Anthony Russo,Joe Russo           Action,Adventure,Sci-Fi
# 3                 Robert Zemeckis           Adventure,Comedy,Sci-Fi
# 4                    Sergio Leone                           Western
#
#                         Country                 Language  Runtime  Netflix  \
# ...

# %%
print(mov_ott)
# Out:
#           ID                           Title  Year  Age  IMDb  \
# 0          1                       Inception  2010  13+   8.8
# 1          2                      The Matrix  1999  18+   8.7
# 2          3          Avengers: Infinity War  2018  13+   8.5
# 3          4              Back to the Future  1985   7+   8.5
# 4          5  The Good, the Bad and the Ugly  1966  18+   8.8
# ...      ...                             ...   ...  ...   ...
# 16739  16740       The Ghosts of Buxley Hall  1980  NaN   6.2
# 16740  16741                  The Poof Point  2001   7+   4.7
# 16741  16742           Sharks of Lost Island  2013  NaN   5.7
# 16742  16743              Man Among Cheetahs  2017  NaN   6.6
# 16743  16744                In Beaver Valley  1950  NaN   NaN
#
#        Rotten Tomatoes                       Directors  \
# 0                 0.87               Christopher Nolan
# 1                 0.87  Lana Wachowski,Lilly Wachowski
# ...

# %%
# Create countplot 'Age' x 'Streaming'

sns.countplot(x='Age', hue='Streaming', data=mov_ott)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
# Create countplot 'Age' x 'Netflix'

sns.countplot(x='Age', hue='Netflix', data=mov_ott)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
# Create histogram 'IMDb'

sns.histplot(data = mov_ott, x = 'IMDb')
# Out:
# <AxesSubplot:xlabel='IMDb', ylabel='Count'>

# %%
# Create scatterplot to explore relationship between 'Rotten Tomatoes' and 'IMDb'

sns.scatterplot(x='Rotten Tomatoes', y='IMDb', marker='o', legend='full', data=mov_ott)
# Out:
# <AxesSubplot:xlabel='Rotten Tomatoes', ylabel='IMDb'>

# %%
sns.regplot(x='Rotten Tomatoes', y='IMDb', color='blue', data=mov_ott)
# Out:
# <AxesSubplot:xlabel='Rotten Tomatoes', ylabel='IMDb'>

# %%
# Scatterplot setting colours:
# Import seaborn as sns; sns.set_theme(color_codes=True)

import seaborn as sns; sns.set_theme(color_codes=True)

ax = sns.regplot(x='Rotten Tomatoes', y='IMDb', data=mov_ott)

# %%
sns.regplot(x='Rotten Tomatoes', y='IMDb', marker='o', data=mov_ott)
# Out:
# <AxesSubplot:xlabel='Rotten Tomatoes', ylabel='IMDb'>

# %% [markdown]
# ### 4.1.12 Practical activity: Outlier analysis

# %%
# Merge both tables and refresh on importing libraries

mov_ott = pd.merge(movies, ott)

# %%
mov_ott
# Out:
#           ID                           Title  Year  Age  IMDb  \
# 0          1                       Inception  2010  13+   8.8
# 1          2                      The Matrix  1999  18+   8.7
# 2          3          Avengers: Infinity War  2018  13+   8.5
# 3          4              Back to the Future  1985   7+   8.5
# 4          5  The Good, the Bad and the Ugly  1966  18+   8.8
# ...      ...                             ...   ...  ...   ...
# 16739  16740       The Ghosts of Buxley Hall  1980  NaN   6.2
# 16740  16741                  The Poof Point  2001   7+   4.7
# 16741  16742           Sharks of Lost Island  2013  NaN   5.7
# 16742  16743              Man Among Cheetahs  2017  NaN   6.6
# 16743  16744                In Beaver Valley  1950  NaN   NaN
#
#        Rotten Tomatoes                       Directors  \
# 0                 0.87               Christopher Nolan
# 1                 0.87  Lana Wachowski,Lilly Wachowski
# ...

# %%
# countplot with 'Age' - 'Total Streaming'
# df['C'] = df['A'] + df['B']

mov_ott['Streaming'] = mov_ott['Netflix'] + mov_ott['Hulu'] + mov_ott['Prime Video'] + mov_ott['Disney+']

# %%
mov_ott
# Out:
#           ID                           Title  Year  Age  IMDb  \
# 0          1                       Inception  2010  13+   8.8
# 1          2                      The Matrix  1999  18+   8.7
# 2          3          Avengers: Infinity War  2018  13+   8.5
# 3          4              Back to the Future  1985   7+   8.5
# 4          5  The Good, the Bad and the Ugly  1966  18+   8.8
# ...      ...                             ...   ...  ...   ...
# 16739  16740       The Ghosts of Buxley Hall  1980  NaN   6.2
# 16740  16741                  The Poof Point  2001   7+   4.7
# 16741  16742           Sharks of Lost Island  2013  NaN   5.7
# 16742  16743              Man Among Cheetahs  2017  NaN   6.6
# 16743  16744                In Beaver Valley  1950  NaN   NaN
#
#        Rotten Tomatoes                       Directors  \
# 0                 0.87               Christopher Nolan
# 1                 0.87  Lana Wachowski,Lilly Wachowski
# ...

# %%
# Plot a boxplot to display the outliers when comparing the user age and their IMDb ratings for the movies.

sns.boxplot(x='Age', y='IMDb', data=mov_ott)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='IMDb'>

# %%
# Remove the outliers from the plot (adding showfliers=False)

sns.boxplot(x='Age', y='IMDb', showfliers=False, data=mov_ott)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='IMDb'>

# %% [markdown]
# ### 4.1.15 Practical activity: Create line and subplots

# %%
# Plot a lineplot to identify possible trends by comparing the movies' release year and their IMDb ratings

sns.lineplot(x='Year', y='IMDb', data=mov_ott)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='IMDb'>

# %%
# Enhance the lineplot to include a comparison between the age, rating, and year of release of the movies

sns.lineplot(x='Year', y='IMDb', hue='Age', data=mov_ott, ci=None)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='IMDb'>

# %%
# Improving it selecting only 16+ and 18+

mov_ott_1618 = mov_ott[mov_ott['Age'].isin(['16+', '18+'])]

# %%
mov_ott_1618
# Out:
#           ID                           Title  Year  Age  IMDb  \
# 1          2                      The Matrix  1999  18+   8.7
# 4          5  The Good, the Bad and the Ugly  1966  18+   8.8
# 6          7                     The Pianist  2002  18+   8.5
# 7          8                Django Unchained  2012  18+   8.4
# 9         10            Inglourious Basterds  2009  18+   8.3
# ...      ...                             ...   ...  ...   ...
# 15851  15852                     The Wickeds  2005  18+   2.8
# 15857  15858                Enemies Among Us  2010  18+   2.2
# 15979  15980            Long Live Your Death  2015  18+   NaN
# 16136  16137            Love & I Had A Fight  2013  18+   NaN
# 16611  16612                     Life-Size 2  2018  16+   4.8
#
#        Rotten Tomatoes                       Directors  \
# 1                 0.87  Lana Wachowski,Lilly Wachowski
# 4                 0.97                    Sergio Leone
# ...

# %%
sns.lineplot(x='Year', y='IMDb', hue='Age', data=mov_ott_1618, ci=None)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='IMDb'>

# %% [markdown]
# ### TIMEPLOT - TIME SERIES

# %%
# Import Matplotlib, Seaborn, and Pandas.
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.dates import *

# Import * means import everything.

# %%
weather
# Out:
#             date   TimeEST  TemperatureF  Dew PointF  Humidity Wind SpeedMPH  \
# 0     2016-01-01  12:51 AM          42.1        25.0      51.0           4.6
# 1     2016-01-01   1:51 AM          41.0        25.0      53.0           3.5
# 2     2016-01-01   2:51 AM          41.0        26.1      55.0           4.6
# 3     2016-01-01   3:51 AM          41.0        26.1      55.0           9.2
# 4     2016-01-01   4:51 AM          39.9        26.1      58.0          10.4
# ...          ...       ...           ...         ...       ...           ...
# 5136  2016-06-30   7:51 PM          78.1        60.1      54.0           5.8
# 5137  2016-07-01   8:51 PM          77.0        61.0      58.0           3.5
# 5138  2016-07-01   9:51 PM          75.9        61.0      60.0          Calm
# 5139  2016-07-01  10:51 PM          75.9        61.0      60.0           4.6
# 5140  2016-07-01  11:51 PM          75.9        60.1      58.0           3.5
#
#          Conditions
# 0          Overcast
# ...

# %%
# Read the CSV file.
weather = pd.read_csv('ny_hourly.csv')

# View the DataFrame.
print(weather.shape)
print(weather.dtypes)
print(weather.columns)
weather.head()
# Out:
# (5141, 7)
# date              object
# TimeEST           object
# TemperatureF     float64
# Dew PointF       float64
# Humidity         float64
# Wind SpeedMPH     object
# Conditions        object
# dtype: object
# Index(['date', 'TimeEST', 'TemperatureF', 'Dew PointF', 'Humidity',
#        'Wind SpeedMPH', 'Conditions'],
#       dtype='object')
#          date   TimeEST  TemperatureF  Dew PointF  Humidity Wind SpeedMPH  \
# 0  2016-01-01  12:51 AM          42.1        25.0      51.0           4.6
# 1  2016-01-01   1:51 AM          41.0        25.0      53.0           3.5
# 2  2016-01-01   2:51 AM          41.0        26.1      55.0           4.6
# 3  2016-01-01   3:51 AM          41.0        26.1      55.0           9.2
# 4  2016-01-01   4:51 AM          39.9        26.1      58.0          10.4
#
#   Conditions
# 0   Overcast
# 1   Overcast
# 2   Overcast
# 3   Overcast
# 4   Overcast

# %%
# We do DATA PREP first
# We will be interested in three main variables: "TemperatureF', 'Dew PointF', 'Humidity'
# We want to combine date and time together into one object

# Import data again with parse.
weather = pd.read_csv('ny_hourly.csv',
                      parse_dates=[['date', 'TimeEST']],
                      usecols=['date', 'TimeEST', 'TemperatureF', 'Dew PointF', 'Humidity'])

# %%
weather
# Out:
#             date_TimeEST  TemperatureF  Dew PointF  Humidity
# 0    2016-01-01 00:51:00          42.1        25.0      51.0
# 1    2016-01-01 01:51:00          41.0        25.0      53.0
# 2    2016-01-01 02:51:00          41.0        26.1      55.0
# 3    2016-01-01 03:51:00          41.0        26.1      55.0
# 4    2016-01-01 04:51:00          39.9        26.1      58.0
# ...                  ...           ...         ...       ...
# 5136 2016-06-30 19:51:00          78.1        60.1      54.0
# 5137 2016-07-01 20:51:00          77.0        61.0      58.0
# 5138 2016-07-01 21:51:00          75.9        61.0      60.0
# 5139 2016-07-01 22:51:00          75.9        61.0      60.0
# 5140 2016-07-01 23:51:00          75.9        60.1      58.0
#
# [5141 rows x 4 columns]

# %%
weather.describe()
# Out:
#        TemperatureF   Dew PointF     Humidity
# count   5141.000000  5141.000000  5137.000000
# mean      42.943649    27.130247    58.341250
# std      280.702231   280.354764    20.746395
# min    -9999.000000 -9999.000000     9.000000
# 25%       37.900000    23.000000    42.000000
# 50%       50.000000    35.100000    55.000000
# 75%       63.000000    48.000000    78.000000
# max       90.000000    69.800000   100.000000

# %%
# As we can see we have outliers. We will restrict vales to values that make sense. 
# We will also sort out the data according to the date.

# Only values bigger than -100.
weather = weather[weather['TemperatureF'] >-100]

# Sort data.
weather = weather.sort_values('date_TimeEST')

# %%
weather
# Out:
#             date_TimeEST  TemperatureF  Dew PointF  Humidity
# 0    2016-01-01 00:51:00          42.1        25.0      51.0
# 1    2016-01-01 01:51:00          41.0        25.0      53.0
# 2    2016-01-01 02:51:00          41.0        26.1      55.0
# 3    2016-01-01 03:51:00          41.0        26.1      55.0
# 4    2016-01-01 04:51:00          39.9        26.1      58.0
# ...                  ...           ...         ...       ...
# 5116 2016-06-30 23:51:00          73.0        57.0      57.0
# 5137 2016-07-01 20:51:00          77.0        61.0      58.0
# 5138 2016-07-01 21:51:00          75.9        61.0      60.0
# 5139 2016-07-01 22:51:00          75.9        61.0      60.0
# 5140 2016-07-01 23:51:00          75.9        60.1      58.0
#
# [5137 rows x 4 columns]

# %%
weather.describe()
# Out:
#        TemperatureF   Dew PointF     Humidity
# count   5137.000000  5137.000000  5137.000000
# mean      50.762955    34.937240    58.341250
# std       16.051068    17.603468    20.746395
# min       -0.900000   -18.900000     9.000000
# 25%       37.900000    23.000000    42.000000
# 50%       50.000000    35.100000    55.000000
# 75%       63.000000    48.000000    78.000000
# max       90.000000    69.800000   100.000000

# %%
# How temperature changes over time.
# Seaborn lineplots.
sns.lineplot(x='date_TimeEST', y='TemperatureF',
            data=weather).set_title("Hourly Weather in New York")
# Out:
# Text(0.5, 1.0, 'Hourly Weather in New York')

# %%
# Adding 'Dewpoint' and 'Humidity' in the Seaborn lineplot.

sns.lineplot(x='date_TimeEST', y='Dew PointF', data=weather).set_title("Hourly Weather in New York")
# Out:
# Text(0.5, 1.0, 'Hourly Weather in New York')

# %%
sns.lineplot(x='date_TimeEST', y='Humidity', data=weather).set_title("Hourly Weather in New York")
# Out:
# Text(0.5, 1.0, 'Hourly Weather in New York')

# %%
# Format dates.
fig, ax = plt.subplots()

sns.lineplot(x='date_TimeEST', y='TemperatureF',
             data=weather).set_title("Hourly Weather in New York")

x_labels = weather['date_TimeEST'].dt.strftime('%Y-%m-%d')

# What we do is use from "Datetime" (.dt) use a command which is transform a column format, "string
# from time" (.strftime), choosing now the exact format we want the data to be displayed like (in our 
# case, year %Y - month %m - day %d). With the command set_xticklabels we can also rotate ticks.

ax.set_xticklabels(x_labels, rotation=45)

plt.show()
# Out:
# /var/folders/_k/8h4zfdrd3qgd4kzz6qhbbzyh0000gn/T/ipykernel_1204/3401635728.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x_labels, rotation=45)

# %%
# Plotting different variables.
january_data = weather[weather.date_TimeEST < np.datetime64('2016-01-03')]

# We restrict the data to the first days of January, we are going to use the TWINX method.
# TWINX is a plot with different Y axis but same X

fig, temp_ax = plt.subplots()
fig.set_size_inches(14, 8)

# We duplicate the axis.

humidity_ax = temp_ax.twinx()

temp_lines = temp_ax.plot(january_data.date_TimeEST, january_data.TemperatureF, 'r')
humidity_lines = humidity_ax.plot(january_data.date_TimeEST, january_data.Humidity, 'c')

# %%
# We embellish now the axes.

# Add labels.
temp_ax.set_title("Hourly Temperature in NYC")
temp_ax.set_xlabel("Date & Time")
temp_ax.set_ylabel("Temperature (ºF)")

humidity_ax.set_ylabel("Humidity (%)")

# Change date and time (from the Matplotlib locator)
major_locator = AutoDateLocator()
formatter = ConciseDateFormatter(major_locator)
humidity_ax.xaxis.set_major_formatter(formatter)
temp_ax.xaxis.set_major_formatter(formatter)

fig

# %%
# Now we want to plot the initial three plots in a common space

# Plot multiple variables with the same x-axis: we tell python we want
# 3 subplots on top of each other: nrows=3.

fig, axes = plt.subplots(nrows=3)
nyc_fig = fig
fig.set_size_inches(14, 10)

# Now we define our 3 subplots.

temp_lines = axes[0].plot(weather.date_TimeEST, weather.TemperatureF, 'r')
humidity_lines = axes[1].plot(weather.date_TimeEST, weather.Humidity, 'c')
dew_point_lines = axes[2].plot(weather.date_TimeEST, weather['Dew PointF'], 'g')

# We are not formatting the first two axis, we only format the third (axis[2]).
# 0 and 1 are kept untouched.

axes[0].set_xticklabels([])
axes[1].set_xticklabels([])

# Now we format axis[2]

major_locator = AutoDateLocator()
formatter = ConciseDateFormatter(major_locator)
axes[2].xaxis.set_major_formatter(formatter)

# Now we add some labels to the axis

axes[0].set_ylabel("Temperature (ºF)")
axes[1].set_ylabel("Humidity (%)")
axes[2].set_ylabel("Dew Point (ºF)")
axes[2].set_xlabel("Date")
fig.suptitle("Weather in New York City", fontsize=16, y=0.92)
axes[2].legend(temp_lines + humidity_lines + dew_point_lines, 
                ['Temperature', 'Humidity', 'Dew Point'], loc='lower right', ncol=3)

# %% [markdown]
# ### 4.2.5 Practical activity: Customise your plots

# %%
 # Barplot for using the count function to display the number of movies viewed from 2010 to 2020.

# %%
mov_ott_2010 = mov_ott[mov_ott['Year']>= 2010]

# %%
sns.countplot(x='Year', data=mov_ott_2010)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='count'>

# %%
# Modify the barplot using the given code.

mov_ott_2010 = mov_ott[mov_ott['Year']>=2010]

ax = sns.countplot(x='Year', data=mov_ott_2010)

ax.set(ylabel='Percent')

total = len(mov_ott_2010['Year'])

for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x()
    y = p.get_y() + p.get_height()
    ax.annotate(percentage, (x, y))

plt.xticks(rotation=90)
plt.show()

# %%
# Now we work with the histogram 'IMDb' we have already created.
# Let's add the given code to see the distribution.

sns.histplot(data = mov_ott, x = 'IMDb')

ax = sns.displot(data=mov_ott, x='IMDb', bins=10,kind='hist', 
                 palette='GnBu', aspect=1.4, kde=True)

plt.show()

# %% [markdown]
# ### 4.2.7 Practical activity: Highlight and annotate your plots

# %%
# We are going to work with the previous IMDb/RT Scatterplot
# Import seaborn as sns; sns.set_theme(color_codes=True)

import seaborn as sns; sns.set_theme(color_codes=True)

ax = sns.scatterplot(x='Rotten Tomatoes', y='IMDb', data=mov_ott)

# %%
import seaborn as sns; sns.set_theme(color_codes=True)

ax = sns.scatterplot(x='Rotten Tomatoes', y='IMDb', hue='Netflix', data=mov_ott)

# %%
sns.boxplot(data=mov_ott, x='Age', y='IMDb', linewidth=2, 
            notch=True, hue='Netflix', palette='Set3')

plt.show()

# %%
sns.lineplot(x = 'Year', y = 'IMDb', data=mov_ott, linewidth=0)

sns.lineplot(x = 'Year', y = 'IMDb',
             data=mov_ott[mov_ott['Age'].isin(['16+', '18+'])], 
             hue ='Age')

sns.lineplot(x = 'Year', y = 'IMDb', 
             data=mov_ott[mov_ott['Age'].isin(['16+', '18+'])], 
             hue ='Age', style = 'Age', markers=True, ci=0)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='IMDb'>
